# %%
import keras

from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, MaxPooling2D, Conv2D, Dropout
from keras.layers import Flatten
from keras.datasets import mnist
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
img_rows, img_cols = 28, 28
batch_size = 128
num_classes = 10

# %%
x_train = x_train.reshape(x_train.shape[0],img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0],img_rows, img_cols, 1)
#only grey scale

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# %%
x_train /= 255
x_test /= 255

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
y_train.shape
# Out:
# (60000, 10)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3), input_shape=(28,28,1)))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# activation_1 (Activation)    (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 11, 11, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               204928
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 241,546
# Trainable params: 241,546
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
             optimizer='rmsprop',
             metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=1, batch_size=128, verbose=1)
# Out:
# Epoch 1/1
# 60000/60000 [==============================] - 90s - loss: 0.2437 - acc: 0.9220

# %%
score = model.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 5s

# %%
score
# Out:
# [0.10060899823755026, 0.96519999999999995]

# %%
model.fit(x_train, y_train, epochs=1, batch_size=128, verbose=1)
# Out:
# Epoch 1/1
# 60000/60000 [==============================] - 93s - loss: 0.0648 - acc: 0.9800

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  9984/10000 [============================>.] - ETA: 0s

# %%
score
# Out:
# [0.034280833658482876, 0.98880000000000001]

# %%
model.save('model.h5')

# %%
model.fit(x_train, y_train, epochs=1, batch_size=128, verbose=1)
# Out:
# Epoch 1/1
#  - ETA: 7s - loss: 0.0470 - acc: 0.9849

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  9952/10000 [============================>.] - ETA: 0s

# %%
score
# Out:
# [0.038309307500999423, 0.98680000000000001]

# %%
model.fit(x_train, y_train, epochs=1, batch_size=128, verbose=1)
# Out:
# Epoch 1/1
#  - ETA: 3s - loss: 0.0373 - acc: 0.9887

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  - ETA: 4s

# %%
score
# Out:
# [0.027681831336033066, 0.99039999999999995]

# %%
model.save('model.h5')

# %%
model.fit(x_train, y_train, epochs=1, batch_size=128, verbose=1)
# Out:
# Epoch 1/1
#  - ETA: 31s - loss: 0.0308 - acc: 0.9905

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  9920/10000 [============================>.] - ETA: 0s

# %%
score
# Out:
# [0.031073155777568171, 0.99009999999999998]

# %%
model.fit(x_train, y_train, epochs=1, batch_size=128, verbose=1)
# Out:
# Epoch 1/1
#  - ETA: 21s - loss: 0.0261 - acc: 0.9918

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  9952/10000 [============================>.] - ETA: 0s

# %%
score
# Out:
# [0.024550352687202393, 0.99199999999999999]

# %%
model.fit(x_train, y_train, epochs=1, batch_size=128, verbose=1)
# Out:
# Epoch 1/1
# 60000/60000 [==============================] - 90s - loss: 0.0243 - acc: 0.9920

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  9952/10000 [============================>.] - ETA: 0s

# %%
score
# Out:
# [0.021548798947189425, 0.99309999999999998]

# %%
model.fit(x_train, y_train, epochs=1, batch_size=128, verbose=1)
# Out:
# Epoch 1/1
# 60000/60000 [==============================] - 89s - loss: 0.0215 - acc: 0.9934

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  9920/10000 [============================>.] - ETA: 0s

# %%
score
# Out:
# [0.022461666260465425, 0.99299999999999999]

# %%
model.fit(x_train, y_train, epochs=1, batch_size=128, verbose=1)
# Out:
# Epoch 1/1
#  - ETA: 24s - loss: 0.0181 - acc: 0.9940

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  9952/10000 [============================>.] - ETA: 0s

# %%
score
# Out:
# [0.022840213276369377, 0.99419999999999997]

# %%
model.save('model.h5')

# %%
model.fit(x_train, y_train, epochs=2, batch_size=128, verbose=1)
# Out:
# Epoch 1/2
#  - ETA: 51s - loss: 0.0165 - acc: 0.9946
# Epoch 2/2
# 60000/60000 [==============================] - 95s - loss: 0.0167 - acc: 0.9946

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  9984/10000 [============================>.] - ETA: 0s

# %%
score
# Out:
# [0.024660098225155708, 0.9929]

# %%
model.fit(x_train, y_train, epochs=2, batch_size=128, verbose=1)
# Out:
# Epoch 1/2
#  - ETA: 1s - loss: 0.0162 - acc: 0.9953
# Epoch 2/2
# 60000/60000 [==============================] - 95s - loss: 0.0141 - acc: 0.9956

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  9984/10000 [============================>.] - ETA: 0s

# %%
score
# Out:
# [0.025312217423672699, 0.99380000000000002]

# %%
model.fit(x_train, y_train, epochs=2, batch_size=128, verbose=1)
# Out:
# Epoch 1/2
#  - ETA: 1s - loss: 0.0145 - acc: 0.9956
# Epoch 2/2
#  - ETA: 28s - loss: 0.0149 - acc: 0.9957

# %%
score = model.evaluate(x_test, y_test)
# Out:
#  9952/10000 [============================>.] - ETA: 0s

# %%
score
# Out:
# [0.029747711873693333, 0.99170000000000003]

# %%
model.save('final.h5')
